# %%
import featurize
import tqdm

# %%
featurize.generate_features(34, 33, "features_prediction/")
# Out:
# Maximum month in features after processing will be: 33
# Features of items and shops
# Features of items
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     264             try:
# --> 265                 return self._python_agg_general(func, *args, **kwargs)
#     266             except (ValueError, KeyError):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     935
# --> 936             result, counts = self.grouper.agg_series(obj, f)
#     937             assert result is not None
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     640         try:
# --> 641             return self._aggregate_series_fast(obj, func)
# ...

# %%
max_labeled_month = 33
for x in range(10):
    featurize.generate_features(max_labeled_month - x, max_labeled_month - 1 - x, "features_train_" + str(x+1) + "/")
